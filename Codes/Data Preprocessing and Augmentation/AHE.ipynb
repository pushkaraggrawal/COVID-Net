# %%
#AUGMENTATION
# import the necessary packages
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img
import numpy as np
from skimage import exposure,io, color
from os import listdir
from os.path import isfile, join
import cv2
# Out:
# Using TensorFlow backend.

# %%
img=io.imread(r"C:\Users\AMAN VERMA\Desktop\Machine Learning\lung-segmentation-2d-master\lung-segmentation-2d-master\Demo\Data\1main.jpg")
io.imsave(r"E:\X.png",exposure.equalize_adapthist(color.rgb2gray(io.imread(r"C:\Users\AMAN VERMA\Desktop\Machine Learning\lung-segmentation-2d-master\lung-segmentation-2d-master\Demo\Data\1main.jpg")), clip_limit =0.02))
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
print(r"E:\NIH Revised\F (" + str(4) + ")")
# Out:
# E:\NIH Revised\F (4)

# %%
print("\")
# Out:
#   File "<ipython-input-25-dff1232de400>", line 1
#     print("\")
#               ^
# SyntaxError: EOL while scanning string literal
